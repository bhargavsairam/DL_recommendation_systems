# %%
# !rm -rf /content/Datasets

# %%
import pandas as pd
import numpy as np

# %%
import os
import zipfile
import requests

if(not os.path.exists("./Datasets/MoviLens.zip")):

  resp = requests.get("http://files.grouplens.org/datasets/movielens/ml-20m.zip")

  os.mkdir("./Datasets")

  with open("./Datasets/MoviLens.zip", "wb") as f:
    f.write(resp.content)

  with zipfile.ZipFile("./Datasets/MoviLens.zip", "r") as zip_ref:
    zip_ref.extractall("./Datasets")

# %%
np.random.seed(123)

ratings = pd.read_csv('/content/Datasets/ml-20m/ratings.csv', parse_dates=['timestamp'])

rand_userIds = np.random.choice(ratings['userId'].unique(),
                                size=int(len(ratings['userId'].unique())*0.1),
                                replace=False)

ratings = ratings.loc[ratings['userId'].isin(rand_userIds)]

# %%
ratings['rank_latest'] = ratings.groupby(['userId'])['timestamp'].rank(method='first', ascending=False)

train_ratings = ratings[ratings['rank_latest'] != 1]
test_ratings = ratings[ratings['rank_latest'] == 1]

# drop columns that we no longer need
train_ratings = train_ratings[['userId', 'movieId', 'rating']]
test_ratings = test_ratings[['userId', 'movieId', 'rating']]

# %%
train_ratings.loc[:, 'rating'] = 1

# %%
# Get a list of all movie IDs
all_movieIds = ratings['movieId'].unique()

# Placeholders that will hold the training data
users, items, labels = [], [], []

# This is the set of items that each user has interaction with
user_item_set = set(zip(train_ratings['userId'], train_ratings['movieId']))

# 4:1 ratio of negative to positive samples
num_negatives = 4

for (u, i) in user_item_set:
    users.append(u)
    items.append(i)
    labels.append(1) # items that the user has interacted with are positive
    for _ in range(num_negatives):
        # randomly select an item
        negative_item = np.random.choice(all_movieIds)
        # check that the user has not interacted with this item
        while (u, negative_item) in user_item_set:
            negative_item = np.random.choice(all_movieIds)
        users.append(u)
        items.append(negative_item)
        labels.append(0) # items not interacted with are negative

# %%
import torch
from torch.utils.data import Dataset

class MovieLensTrainDataset(Dataset):
    """MovieLens PyTorch Dataset for Training

    Args:
        ratings (pd.DataFrame): Dataframe containing the movie ratings
        all_movieIds (list): List containing all movieIds

    """

    def __init__(self, ratings, all_movieIds):
        self.users, self.items, self.labels = self.get_dataset(ratings, all_movieIds)

    def __len__(self):
        return len(self.users)

    def __getitem__(self, idx):
        return self.users[idx], self.items[idx], self.labels[idx]

    def get_dataset(self, ratings, all_movieIds):
        users, items, labels = [], [], []
        user_item_set = set(zip(ratings['userId'], ratings['movieId']))

        num_negatives = 4
        for u, i in user_item_set:
            users.append(u)
            items.append(i)
            labels.append(1)
            for _ in range(num_negatives):
                negative_item = np.random.choice(all_movieIds)
                while (u, negative_item) in user_item_set:
                    negative_item = np.random.choice(all_movieIds)
                users.append(u)
                items.append(negative_item)
                labels.append(0)

        return torch.tensor(users), torch.tensor(items), torch.tensor(labels)

# %%
# !pip install pytorch_lightning
# Out:
# Collecting pytorch_lightning
#   Downloading pytorch_lightning-1.6.1-py3-none-any.whl (582 kB)
#      |████████████████████████████████| 582 kB 36.1 MB/s
# Requirement already satisfied: tqdm>=4.41.0 in /usr/local/lib/python3.7/dist-packages (from pytorch_lightning) (4.64.0)
# Collecting pyDeprecate<0.4.0,>=0.3.1
#   Downloading pyDeprecate-0.3.2-py3-none-any.whl (10 kB)
# Collecting fsspec[http]!=2021.06.0,>=2021.05.0
#   Downloading fsspec-2022.3.0-py3-none-any.whl (136 kB)
#      |████████████████████████████████| 136 kB 62.3 MB/s
# Requirement already satisfied: torch>=1.8.* in /usr/local/lib/python3.7/dist-packages (from pytorch_lightning) (1.11.0+cu113)
# Collecting torchmetrics>=0.4.1
#   Downloading torchmetrics-0.8.0-py3-none-any.whl (408 kB)
#      |████████████████████████████████| 408 kB 63.9 MB/s
# Requirement already satisfied: tensorboard>=2.2.0 in /usr/local/lib/python3.7/dist-packages (from pytorch_lightning) (2.8.0)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.7/dist-packages (from pytorch_lightning) (4.2.0)
# Requirement already satisfied: numpy>=1.17.2 in /usr/local/lib/python3.7/dist-packages (from pytorch_lightning) (1.21.6)
# Requirement already satisfied: packaging>=17.0 in /usr/local/lib/python3.7/dist-packages (from pytorch_lightning) (21.3)
# Collecting PyYAML>=5.4
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
#      |████████████████████████████████| 596 kB 71.6 MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from fsspec[http]!=2021.06.0,>=2021.05.0->pytorch_lightning) (2.23.0)
# Collecting aiohttp
#   Downloading aiohttp-3.8.1-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 61.5 MB/s
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=17.0->pytorch_lightning) (3.0.8)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch_lightning) (1.35.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch_lightning) (0.4.6)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch_lightning) (1.0.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch_lightning) (1.0.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch_lightning) (0.6.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch_lightning) (3.3.6)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch_lightning) (1.8.1)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch_lightning) (0.37.1)
# Requirement already satisfied: grpcio>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch_lightning) (1.44.0)
# Requirement already satisfied: protobuf>=3.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch_lightning) (3.17.3)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch_lightning) (57.4.0)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from absl-py>=0.4->tensorboard>=2.2.0->pytorch_lightning) (1.15.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch_lightning) (4.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch_lightning) (4.2.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch_lightning) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.2.0->pytorch_lightning) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard>=2.2.0->pytorch_lightning) (4.11.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard>=2.2.0->pytorch_lightning) (3.8.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch_lightning) (0.4.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch_lightning) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch_lightning) (2021.10.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch_lightning) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch_lightning) (2.10)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.2.0->pytorch_lightning) (3.2.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch_lightning) (21.4.0)
# Collecting async-timeout<5.0,>=4.0.0a3
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.3.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (144 kB)
#      |████████████████████████████████| 144 kB 72.9 MB/s
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.0.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (94 kB)
#      |████████████████████████████████| 94 kB 3.2 MB/s
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.2.0-py3-none-any.whl (8.2 kB)
# Collecting asynctest==0.13.0
#   Downloading asynctest-0.13.0-py3-none-any.whl (26 kB)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch_lightning) (2.0.12)
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.7.2-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (271 kB)
#      |████████████████████████████████| 271 kB 70.3 MB/s
# Installing collected packages: multidict, frozenlist, yarl, asynctest, async-timeout, aiosignal, pyDeprecate, fsspec, aiohttp, torchmetrics, PyYAML, pytorch-lightning
#   Attempting uninstall: PyYAML
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# Successfully installed PyYAML-6.0 aiohttp-3.8.1 aiosignal-1.2.0 async-timeout-4.0.2 asynctest-0.13.0 frozenlist-1.3.0 fsspec-2022.3.0 multidict-6.0.2 pyDeprecate-0.3.2 pytorch-lightning-1.6.1 torchmetrics-0.8.0 yarl-1.7.2

# %%
import torch.nn as nn
import pytorch_lightning as pl
from torch.utils.data import DataLoader

class NCF(pl.LightningModule):
    """ Neural Collaborative Filtering (NCF)

        Args:
            num_users (int): Number of unique users
            num_items (int): Number of unique items
            ratings (pd.DataFrame): Dataframe containing the movie ratings for training
            all_movieIds (list): List containing all movieIds (train + test)
    """

    def __init__(self, num_users, num_items, ratings, all_movieIds):
        super().__init__()
        self.user_embedding = nn.Embedding(num_embeddings=num_users, embedding_dim=8)
        self.item_embedding = nn.Embedding(num_embeddings=num_items, embedding_dim=8)
        self.fc1 = nn.Linear(in_features=16, out_features=64)
        self.fc2 = nn.Linear(in_features=64, out_features=32)
        self.output = nn.Linear(in_features=32, out_features=1)
        self.ratings = ratings
        self.all_movieIds = all_movieIds

    def forward(self, user_input, item_input):

        # Pass through embedding layers
        user_embedded = self.user_embedding(user_input)
        item_embedded = self.item_embedding(item_input)

        # Concat the two embedding layers
        vector = torch.cat([user_embedded, item_embedded], dim=-1)

        # Pass through dense layer
        vector = nn.ReLU()(self.fc1(vector))
        vector = nn.ReLU()(self.fc2(vector))

        # Output layer
        pred = nn.Sigmoid()(self.output(vector))

        return pred

    def training_step(self, batch, batch_idx):
        user_input, item_input, labels = batch
        predicted_labels = self(user_input, item_input)
        loss = nn.BCELoss()(predicted_labels, labels.view(-1, 1).float())
        return loss

    def configure_optimizers(self):
        return torch.optim.Adam(self.parameters())

    def train_dataloader(self):
        return DataLoader(MovieLensTrainDataset(self.ratings, self.all_movieIds),
                          batch_size=512, num_workers=4)

# %%
num_users = ratings['userId'].max()+1
num_items = ratings['movieId'].max()+1
all_movieIds = ratings['movieId'].unique()

model = NCF(num_users, num_items, train_ratings, all_movieIds)

trainer = pl.Trainer(max_epochs = 4,
                      gpus = 1,
                     reload_dataloaders_every_n_epochs = True,
                     progress_bar_refresh_rate = 50,
                     logger = False,
                     checkpoint_callback = False)

trainer.fit(model)
# Out:
# /usr/local/lib/python3.7/dist-packages/pytorch_lightning/trainer/connectors/callback_connector.py:152: LightningDeprecationWarning: Setting `Trainer(checkpoint_callback=False)` is deprecated in v1.5 and will be removed in v1.7. Please consider using `Trainer(enable_checkpointing=False)`.
#   f"Setting `Trainer(checkpoint_callback={checkpoint_callback})` is deprecated in v1.5 and will "
# /usr/local/lib/python3.7/dist-packages/pytorch_lightning/trainer/connectors/callback_connector.py:97: LightningDeprecationWarning: Setting `Trainer(progress_bar_refresh_rate=50)` is deprecated in v1.5 and will be removed in v1.7. Please pass `pytorch_lightning.callbacks.progress.TQDMProgressBar` with `refresh_rate` directly to the Trainer's `callbacks` argument instead. Or, to disable the progress bar pass `enable_progress_bar = False` to the Trainer.
#   f"Setting `Trainer(progress_bar_refresh_rate={progress_bar_refresh_rate})` is deprecated in v1.5 and"
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name           | Type      | Params
# ---------------------------------------------
# 0 | user_embedding | Embedding | 1.1 M
# 1 | item_embedding | Embedding | 1.0 M
# 2 | fc1            | Linear    | 1.1 K
# 3 | fc2            | Linear    | 2.1 K
# 4 | output         | Linear    | 33
# ---------------------------------------------
# 2.2 M     Trainable params
# 0         Non-trainable params
# 2.2 M     Total params
# 8.642     Total estimated model params size (MB)
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Training: 0it [00:00, ?it/s]

# %%
# User-item pairs for testing
test_user_item_set = set(zip(test_ratings['userId'], test_ratings['movieId']))

# Dict of all items that are interacted with by each user
user_interacted_items = ratings.groupby('userId')['movieId'].apply(list).to_dict()

hits = []
for (u,i) in test_user_item_set:
    interacted_items = user_interacted_items[u]
    not_interacted_items = set(all_movieIds) - set(interacted_items)
    selected_not_interacted = list(np.random.choice(list(not_interacted_items), 99))
    test_items = selected_not_interacted + [i]

    predicted_labels = np.squeeze(model(torch.tensor([u]*100),
                                        torch.tensor(test_items)).detach().numpy())

    top10_items = [test_items[i] for i in np.argsort(predicted_labels)[::-1][0:10].tolist()]

    if i in top10_items:
        hits.append(1)
    else:
        hits.append(0)

print("The Hit Ratio @ 10 is {:.2f}".format(np.average(hits)))
print(top10_items)
# Out:
# The Hit Ratio @ 10 is 0.78
# [48774, 6, 1876, 2186, 1635, 4903, 8917, 4823, 3019, 1086]

# %%
print(ratings.head())
# Out:
#      userId  movieId  rating  timestamp  rank_latest
# 236       3        1     4.0  944919407         81.0
# 237       3       24     3.0  945176048         10.0
# 238       3       32     4.0  944918047        140.0
# 239       3       50     5.0  944918018        143.0
# 240       3      160     3.0  945176048         11.0

# %%
ratings.head(10)
# Out:
#      userId  movieId  rating  timestamp  rank_latest
# 236       3        1     4.0  944919407         81.0
# 237       3       24     3.0  945176048         10.0
# 238       3       32     4.0  944918047        140.0
# 239       3       50     5.0  944918018        143.0
# 240       3      160     3.0  945176048         11.0
# 241       3      173     2.0  945176099          1.0
# 242       3      175     5.0  944919133         89.0
# 243       3      196     3.0  945175939         25.0
# 244       3      223     5.0  944918444        116.0
# 245       3      260     5.0  944917742        152.0

# %%
new_ratings = pd.read_csv('/content/Datasets/ml-20m/movies.csv')
new_ratings.head(10)
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
# 5        6                         Heat (1995)
# 6        7                      Sabrina (1995)
# 7        8                 Tom and Huck (1995)
# 8        9                 Sudden Death (1995)
# 9       10                    GoldenEye (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy
# 5                        Action|Crime|Thriller
# 6                               Comedy|Romance
# 7                           Adventure|Children
# 8                                       Action
# 9                    Action|Adventure|Thriller

# %%
for j in user_interacted_items[u]:
  print(new_ratings[new_ratings['movieId'] == j]['title'])
# Out:
# 0    Toy Story (1995)
# Name: title, dtype: object
# 1    Jumanji (1995)
# Name: title, dtype: object
# 16    Sense and Sensibility (1995)
# Name: title, dtype: object
# 31    Twelve Monkeys (a.k.a. 12 Monkeys) (1995)
# Name: title, dtype: object
# 33    Babe (1995)
# Name: title, dtype: object
# 35    Dead Man Walking (1995)
# Name: title, dtype: object
# 38    Clueless (1995)
# Name: title, dtype: object
# 43    Mortal Kombat (1995)
# Name: title, dtype: object
# 46    Seven (a.k.a. Se7en) (1995)
# Name: title, dtype: object
# 49    Usual Suspects, The (1995)
# Name: title, dtype: object
# 102    Happy Gilmore (1996)
# Name: title, dtype: object
# 108    Braveheart (1995)
# Name: title, dtype: object
# 148    Apollo 13 (1995)
# Name: title, dtype: object
# 206    Waterworld (1995)
# Name: title, dtype: object
# 214    Billy Madison (1995)
# Name: title, dtype: object
# 228    Dumb & Dumber (Dumb and Dumber) (1994)
# Name: title, dtype: object
# 293    Pulp Fiction (1994)
# Name: title, dtype: object
# 338    Muriel's Wedding (1994)
# Name: title, dtype: object
# 340    Ace Ventura: Pet Detective (1994)
# Name: title, dtype: object
# 352    Forrest Gump (1994)
# Name: title, dtype: object
# 363    Mask, The (1994)
# Name: title, dtype: object
# 368    Reality Bites (1994)
# Name: title, dtype: object
# 373    Speed (1994)
# Name: title, dtype: object
# 431    Coneheads (1993)
# Name: title, dtype: object
# 451    Free Willy (1993)
# Name: title, dtype: object
# 476    Jurassic Park (1993)
# Name: title, dtype: object
# 496    Mrs. Doubtfire (1993)
# Name: title, dtype: object
# 523    Schindler's List (1993)
# Name: title, dtype: object
# 547    Nightmare Before Christmas, The (1993)
# Name: title, dtype: object
# 580    Home Alone (1990)
# Name: title, dtype: object
# 581    Ghost (1990)
# Name: title, dtype: object
# 607    Jane Eyre (1996)
# Name: title, dtype: object
# 724    Twister (1996)
# Name: title, dtype: object
# 765    Trainspotting (1996)
# Name: title, dtype: object
# 767    Independence Day (a.k.a. ID4) (1996)
# Name: title, dtype: object
# 771    Cable Guy, The (1996)
# Name: title, dtype: object
# 775    Nutty Professor, The (1996)
# Name: title, dtype: object
# 822    Matilda (1996)
# Name: title, dtype: object
# 823    Emma (1996)
# Name: title, dtype: object
# 1009    Mary Poppins (1964)
# Name: title, dtype: object
# 1023    That Thing You Do! (1996)
# Name: title, dtype: object
# 1039    William Shakespeare's Romeo + Juliet (1996)
# Name: title, dtype: object
# 1075    E.T. the Extra-Terrestrial (1982)
# Name: title, dtype: object
# 1097    People vs. Larry Flynt, The (1996)
# Name: title, dtype: object
# 1113    Monty Python and the Holy Grail (1975)
# Name: title, dtype: object
# 1169    One Flew Over the Cuckoo's Nest (1975)
# Name: title, dtype: object
# 1180    Clockwork Orange, A (1971)
# Name: title, dtype: object
# 1182    Apocalypse Now (1979)
# Name: title, dtype: object
# 1188    Alien (1979)
# Name: title, dtype: object
# 1196    Full Metal Jacket (1987)
# Name: title, dtype: object
# 1230    Shining, The (1980)
# Name: title, dtype: object
# 1237    Groundhog Day (1993)
# Name: title, dtype: object
# 1242    Back to the Future (1985)
# Name: title, dtype: object
# 1266    Unbearable Lightness of Being, The (1988)
# Name: title, dtype: object
# 1269    Pink Floyd: The Wall (1982)
# Name: title, dtype: object
# 1278    When Harry Met Sally... (1989)
# Name: title, dtype: object
# 1349    Grease (1978)
# Name: title, dtype: object
# 1360    Mars Attacks! (1996)
# Name: title, dtype: object
# 1372    Beavis and Butt-Head Do America (1996)
# Name: title, dtype: object
# 1374    Scream (1996)
# Name: title, dtype: object
# 1445    Liar Liar (1997)
# Name: title, dtype: object
# 1480    Fifth Element, The (1997)
# Name: title, dtype: object
# 1518    My Best Friend's Wedding (1997)
# Name: title, dtype: object
# 1587    I Know What You Did Last Summer (1997)
# Name: title, dtype: object
# 1596    Gattaca (1997)
# Name: title, dtype: object
# 1625    Truman Show, The (1998)
# Name: title, dtype: object
# 1633    Alien: Resurrection (1997)
# Name: title, dtype: object
# 1648    Home Alone 3 (1997)
# Name: title, dtype: object
# 1661    Titanic (1997)
# Name: title, dtype: object
# 1727    Man in the Iron Mask, The (1998)
# Name: title, dtype: object
# 1798    Godzilla (1998)
# Name: title, dtype: object
# 1800    Fear and Loathing in Las Vegas (1998)
# Name: title, dtype: object
# 1827    Dr. Dolittle (1998)
# Name: title, dtype: object
# 1833    Armageddon (1998)
# Name: title, dtype: object
# 1839    There's Something About Mary (1998)
# Name: title, dtype: object
# 1884    Breakfast Club, The (1985)
# Name: title, dtype: object
# 1913    Exorcist, The (1973)
# Name: title, dtype: object
# 1927    Back to the Future Part II (1989)
# Name: title, dtype: object
# 1928    Back to the Future Part III (1990)
# Name: title, dtype: object
# 1944    Saving Private Ryan (1998)
# Name: title, dtype: object
# 1970    Honey, I Shrunk the Kids (1989)
# Name: title, dtype: object
# 1984    Fanny and Alexander (Fanny och Alexander) (1982)
# Name: title, dtype: object
# 2032    Lord of the Rings, The (1978)
# Name: title, dtype: object
# 2061    Pretty in Pink (1986)
# Name: title, dtype: object
# 2076    Rosemary's Baby (1968)
# Name: title, dtype: object
# 2163    Say Anything... (1989)
# Name: title, dtype: object
# 2168    Toys (1992)
# Name: title, dtype: object
# 2206    Edward Scissorhands (1990)
# Name: title, dtype: object
# 2216    History of the World: Part I (1981)
# Name: title, dtype: object
# 2244    American History X (1998)
# Name: title, dtype: object
# 2311    Shakespeare in Love (1998)
# Name: title, dtype: object
# 2342    Thin Red Line, The (1998)
# Name: title, dtype: object
# 2346    Patch Adams (1998)
# Name: title, dtype: object
# 2444    Planet of the Apes (1968)
# Name: title, dtype: object
# 2483    Mod Squad, The (1999)
# Name: title, dtype: object
# 2486    Matrix, The (1999)
# Name: title, dtype: object
# 2496    Never Been Kissed (1999)
# Name: title, dtype: object
# 2549    Mummy, The (1959)
# Name: title, dtype: object
# 2585    Notting Hill (1999)
# Name: title, dtype: object
# 2620    American Pie (1999)
# Name: title, dtype: object
# 2624    Blair Witch Project, The (1999)
# Name: title, dtype: object
# 2626    Eyes Wide Shut (1999)
# Name: title, dtype: object
# 2676    Sixth Sense, The (1999)
# Name: title, dtype: object
# 2772    American Beauty (1999)
# Name: title, dtype: object
# 2856    Flashdance (1983)
# Name: title, dtype: object
# 2873    Fight Club (1999)
# Name: title, dtype: object
# 2911    Being John Malkovich (1999)
# Name: title, dtype: object
# 2994    Sleepy Hollow (1999)
# Name: title, dtype: object
# 3027    Toy Story 2 (1999)
# Name: title, dtype: object
# 3166    Wayne's World (1992)
# Name: title, dtype: object
# 3213    Pitch Black (2000)
# Name: title, dtype: object
# 3320    Erin Brockovich (2000)
# Name: title, dtype: object
# 3321    Final Destination (2000)
# Name: title, dtype: object
# 3329    Thelma & Louise (1991)
# Name: title, dtype: object
# 3399    Hook (1991)
# Name: title, dtype: object
# 3443    28 Days (2000)
# Name: title, dtype: object
# 3487    Gladiator (2000)
# Name: title, dtype: object
# 3532    Mission: Impossible II (2000)
# Name: title, dtype: object
# 3661    Me, Myself & Irene (2000)
# Name: title, dtype: object
# 3702    X-Men (2000)
# Name: title, dtype: object
# 3800    Nurse Betty (2000)
# Name: title, dtype: object
# 3804    Almost Famous (2000)
# Name: title, dtype: object
# 3816    Woman on Top (2000)
# Name: title, dtype: object
# 3855    Requiem for a Dream (2000)
# Name: title, dtype: object
# 3873    Billy Elliot (2000)
# Name: title, dtype: object
# 3881    Lucky Numbers (2000)
# Name: title, dtype: object
# 3883    Charlie's Angels (2000)
# Name: title, dtype: object
# 3894    How the Grinch Stole Christmas (a.k.a. The Gri...
# Name: title, dtype: object
# 3912    Transformers: The Movie (1986)
# Name: title, dtype: object
# 3917    Snatch (2000)
# Name: title, dtype: object
# 3924    What Women Want (2000)
# Name: title, dtype: object
# 3928    Cast Away (2000)
# Name: title, dtype: object
# 3931    Miss Congeniality (2000)
# Name: title, dtype: object
# 4067    Mexican, The (2001)
# Name: title, dtype: object
# 4132    Memento (2000)
# Name: title, dtype: object
# 4135    Say It Isn't So (2001)
# Name: title, dtype: object
# 4137    Someone Like You (2001)
# Name: title, dtype: object
# 4152    Bridget Jones's Diary (2001)
# Name: title, dtype: object
# 4204    Knight's Tale, A (2001)
# Name: title, dtype: object
# 4211    Shrek (2001)
# Name: title, dtype: object
# 4213    Moulin Rouge (2001)
# Name: title, dtype: object
# 4249    Swordfish (2001)
# Name: title, dtype: object
# 4273    Dr. Dolittle 2 (2001)
# Name: title, dtype: object
# 4285    Princess and the Warrior, The (Krieger und die...
# Name: title, dtype: object
# 4293    Scary Movie 2 (2001)
# Name: title, dtype: object
# 4352    Legally Blonde (2001)
# Name: title, dtype: object
# 4543    Jurassic Park III (2001)
# Name: title, dtype: object
# 4548    Planet of the Apes (2001)
# Name: title, dtype: object
# 4625    Others, The (2001)
# Name: title, dtype: object
# 4790    Monsters, Inc. (2001)
# Name: title, dtype: object
# 4794    Shallow Hal (2001)
# Name: title, dtype: object
# 4867    Ocean's Eleven (2001)
# Name: title, dtype: object
# 4877    Amelie (Fabuleux destin d'Amélie Poulain, Le) ...
# Name: title, dtype: object
# 4879    Vanilla Sky (2001)
# Name: title, dtype: object
# 4897    Lord of the Rings: The Fellowship of the Ring,...
# Name: title, dtype: object
# 4899    Beautiful Mind, A (2001)
# Name: title, dtype: object
# 4968    The Count of Monte Cristo (2002)
# Name: title, dtype: object
# 5055    40 Days and 40 Nights (2002)
# Name: title, dtype: object
# 5125    Kissing Jessica Stein (2001)
# Name: title, dtype: object
# 5128    And Your Mother Too (Y tu mamá también) (2001)
# Name: title, dtype: object
# 5199    Sweetest Thing, The (2002)
# Name: title, dtype: object
# 5202    My Big Fat Greek Wedding (2002)
# Name: title, dtype: object
# 5252    Spider-Man (2002)
# Name: title, dtype: object
# 5283    Importance of Being Earnest, The (2002)
# Name: title, dtype: object
# 5348    Minority Report (2002)
# Name: title, dtype: object
# 5352    Mr. Deeds (2002)
# Name: title, dtype: object
# 5380    Sex and Lucia (Lucía y el sexo) (2001)
# Name: title, dtype: object
# 5406    Last Kiss, The (Ultimo bacio, L') (2001)
# Name: title, dtype: object
# 5410    xXx (2002)
# Name: title, dtype: object
# 5475    Barbershop (2002)
# Name: title, dtype: object
# 5509    Das Experiment (Experiment, The) (2001)
# Name: title, dtype: object
# 5518    Secretary (2002)
# Name: title, dtype: object
# 5580    Ring, The (2002)
# Name: title, dtype: object
# 5686    Jackass: The Movie (2002)
# Name: title, dtype: object
# 5773    Die Another Day (2002)
# Name: title, dtype: object
# 5786    What to Do in Case of Fire (Was tun, wenn's br...
# Name: title, dtype: object
# 5801    Analyze That (2002)
# Name: title, dtype: object
# 5844    Maid in Manhattan (2002)
# Name: title, dtype: object
# 5853    Lord of the Rings: The Two Towers, The (2002)
# Name: title, dtype: object
# 5858    Two Weeks Notice (2002)
# Name: title, dtype: object
# 5892    Chicago (2002)
# Name: title, dtype: object
# 5893    Hours, The (2002)
# Name: title, dtype: object
# 5907    Just Married (2003)
# Name: title, dtype: object
# 5917    City of God (Cidade de Deus) (2002)
# Name: title, dtype: object
# 6056    How to Lose a Guy in 10 Days (2003)
# Name: title, dtype: object
# 6119    Bend It Like Beckham (2002)
# Name: title, dtype: object
# 6260    Matrix Reloaded, The (2003)
# Name: title, dtype: object
# 6262    Down with Love (2003)
# Name: title, dtype: object
# 6271    Finding Nemo (2003)
# Name: title, dtype: object
# 6424    Hulk (2003)
# Name: title, dtype: object
# 6425    Legally Blonde 2: Red, White & Blonde (2003)
# Name: title, dtype: object
# 6477    Gigli (2003)
# Name: title, dtype: object
# 6483    Freaky Friday (2003)
# Name: title, dtype: object
# 6599    Once Upon a Time in Mexico (2003)
# Name: title, dtype: object
# 6601    Lost in Translation (2003)
# Name: title, dtype: object
# 6683    Beethoven (1992)
# Name: title, dtype: object
# 6753    School of Rock (2003)
# Name: title, dtype: object
# 6764    Kill Bill: Vol. 1 (2003)
# Name: title, dtype: object
# 6841    21 Grams (2003)
# Name: title, dtype: object
# 7030    Honey (2003)
# Name: title, dtype: object
# 7035    Big Fish (2003)
# Name: title, dtype: object
# 7037    Something's Gotta Give (2003)
# Name: title, dtype: object
# 7041    Lord of the Rings: The Return of the King, The...
# Name: title, dtype: object
# 7042    Mona Lisa Smile (2003)
# Name: title, dtype: object
# 7050    Cold Mountain (2003)
# Name: title, dtype: object
# 7061    Along Came Polly (2004)
# Name: title, dtype: object
# 7142    The Butterfly Effect (2004)
# Name: title, dtype: object
# 7143    Win a Date with Tad Hamilton! (2004)
# Name: title, dtype: object
# 7181    50 First Dates (2004)
# Name: title, dtype: object
# 7208    Dirty Dancing: Havana Nights (2004)
# Name: title, dtype: object
# 7211    Good bye, Lenin! (2003)
# Name: title, dtype: object
# 7234    Girl Next Door, The (2004)
# Name: title, dtype: object
# 7249    Eternal Sunshine of the Spotless Mind (2004)
# Name: title, dtype: object
# 7312    Kill Bill: Vol. 2 (2004)
# Name: title, dtype: object
# 7318    13 Going on 30 (2004)
# Name: title, dtype: object
# 7332    Troy (2004)
# Name: title, dtype: object
# 7762    Day After Tomorrow, The (2004)
# Name: title, dtype: object
# 7767    Saved! (2004)
# Name: title, dtype: object
# 7873    Dodgeball: A True Underdog Story (2004)
# Name: title, dtype: object
# 7874    Terminal, The (2004)
# Name: title, dtype: object
# 7878    Notebook, The (2004)
# Name: title, dtype: object
# 7891    Reconstruction (2003)
# Name: title, dtype: object
# 7955    Before Sunset (2004)
# Name: title, dtype: object
# 7960    Cinderella Story, A (2004)
# Name: title, dtype: object
# 8101    Garden State (2004)
# Name: title, dtype: object
# 8150    Vanity Fair (2004)
# Name: title, dtype: object
# 8178    Resident Evil: Apocalypse (2004)
# Name: title, dtype: object
# 8183    Wimbledon (2004)
# Name: title, dtype: object
# 8227    I Heart Huckabees (2004)
# Name: title, dtype: object
# 8265    Alfie (2004)
# Name: title, dtype: object
# 8275    Ray (2004)
# Name: title, dtype: object
# 8298    Closer (2004)
# Name: title, dtype: object
# 8327    Love Me If You Dare (Jeux d'enfants) (2003)
# Name: title, dtype: object
# 9752    Hitch (2005)
# Name: title, dtype: object
# 9937    Sin City (2005)
# Name: title, dtype: object
# 10151    Mr. & Mrs. Smith (2005)
# Name: title, dtype: object
# 10173    Perfect Man, The (2005)
# Name: title, dtype: object
# 10179    Herbie: Fully Loaded (2005)
# Name: title, dtype: object
# 10182    Bewitched (2005)
# Name: title, dtype: object
# 10194    Edukators, The (Die Fetten Jahre sind vorbei) ...
# Name: title, dtype: object
# 10224    War of the Worlds (2005)
# Name: title, dtype: object
# 10242    Wedding Crashers (2005)
# Name: title, dtype: object
# 10347    40-Year-Old Virgin, The (2005)
# Name: title, dtype: object
# 10415    Domino (2005)
# Name: title, dtype: object
# 10417    Aeon Flux (2005)
# Name: title, dtype: object
# 10430    Corpse Bride (2005)
# Name: title, dtype: object
# 10482    In Her Shoes (2005)
# Name: title, dtype: object
# 10496    Brokeback Mountain (2005)
# Name: title, dtype: object
# 10498    Elizabethtown (2005)
# Name: title, dtype: object
# 10539    Life is a Miracle (Zivot je cudo) (2004)
# Name: title, dtype: object
# 10562    Jarhead (2005)
# Name: title, dtype: object
# 10590    Pride & Prejudice (2005)
# Name: title, dtype: object
# 10600    Harry Potter and the Goblet of Fire (2005)
# Name: title, dtype: object
# 10602    Walk the Line (2005)
# Name: title, dtype: object
# 10608    C.R.A.Z.Y. (2005)
# Name: title, dtype: object
# 10631    Match Point (2005)
# Name: title, dtype: object
# 10646    Family Stone, The (2005)
# Name: title, dtype: object
# 10871    Failure to Launch (2006)
# Name: title, dtype: object
# 10886    V for Vendetta (2006)
# Name: title, dtype: object
# 10888    Thank You for Smoking (2006)
# Name: title, dtype: object
# 10959    Friends with Money (2006)
# Name: title, dtype: object
# 11059    My Super Ex-Girlfriend (2006)
# Name: title, dtype: object
# 11133    Babel (2006)
# Name: title, dtype: object
# 11303    Idiocracy (2006)
# Name: title, dtype: object
# 11309    Fountain, The (2006)
# Name: title, dtype: object
# 11316    Science of Sleep, The (La science des rêves) (...
# Name: title, dtype: object
# 11398    Shortbus (2006)
# Name: title, dtype: object
# 11400    Children of Men (2006)
# Name: title, dtype: object
# 11441    Good Year, A (2006)
# Name: title, dtype: object
# 11458    Holiday, The (2006)
# Name: title, dtype: object
# 11495    Fur: An Imaginary Portrait of Diane Arbus (2006)
# Name: title, dtype: object
# 11642    Music and Lyrics (2007)
# Name: title, dtype: object
# 11817    In the Land of Women (2007)
# Name: title, dtype: object
# 11989    Across the Universe (2007)
# Name: title, dtype: object
# 12032    Superbad (2007)
# Name: title, dtype: object
# 12171    Jane Austen Book Club, The (2007)
# Name: title, dtype: object
# 12232    Beowulf (2007)
# Name: title, dtype: object
# 12262    Alvin and the Chipmunks (2007)
# Name: title, dtype: object
# 12274    Juno (2007)
# Name: title, dtype: object
# 12316    Wristcutters: A Love Story (2006)
# Name: title, dtype: object
# 12321    Sweeney Todd: The Demon Barber of Fleet Street...
# Name: title, dtype: object
# 12342    P.S. I Love You (2007)
# Name: title, dtype: object
# 12423    Caramel (Sukkar banat) (2007)
# Name: title, dtype: object
# 12489    Funny Games U.S. (2007)
# Name: title, dtype: object
# 12552    Smart People (2008)
# Name: title, dtype: object
# 12631    Iron Man (2008)
# Name: title, dtype: object
# 12666    Girl Next Door, The (2007)
# Name: title, dtype: object
# 12684    Sex and the City (2008)
# Name: title, dtype: object
# 12746    WALL·E (2008)
# Name: title, dtype: object
# 12856    Watchmen (2009)
# Name: title, dtype: object
# 12896    Vicky Cristina Barcelona (2008)
# Name: title, dtype: object
# 13050    Zack and Miri Make a Porno (2008)
# Name: title, dtype: object
# 13102    Slumdog Millionaire (2008)
# Name: title, dtype: object
# 13103    Quantum of Solace (2008)
# Name: title, dtype: object
# 13174    Twilight (2008)
# Name: title, dtype: object
# 13269    War of the Worlds (2005)
# Name: title, dtype: object
# 13358    Underworld: Rise of the Lycans (2009)
# Name: title, dtype: object
# 13423    He's Just Not That Into You (2009)
# Name: title, dtype: object
# 13704    Earth (2007)
# Name: title, dtype: object
# 13876    Transformers: Revenge of the Fallen (2009)
# Name: title, dtype: object
# 13935    Harry Potter and the Half-Blood Prince (2009)
# Name: title, dtype: object

# %%
print(new_ratings[new_ratings['movieId'] == i]['title'])
# Out:
# 11400    Children of Men (2006)
# Name: title, dtype: object

# %%
for k in top10_items:
  print(new_ratings[new_ratings['movieId'] == k]['title'])
# Out:
# 583    Terminator 2: Judgment Day (1991)
# Name: title, dtype: object
# 11400    Children of Men (2006)
# Name: title, dtype: object
# 4054    Hannibal (2001)
# Name: title, dtype: object
# 12583    Forgetting Sarah Marshall (2008)
# Name: title, dtype: object
# 4232    Magnificent Seven, The (1960)
# Name: title, dtype: object
# 1962    Flight of the Navigator (1986)
# Name: title, dtype: object
# 10435    Capote (2005)
# Name: title, dtype: object
# 1229    Better Off Dead... (1985)
# Name: title, dtype: object
# 4633    Rat Race (2001)
# Name: title, dtype: object
# 5014    Super Troopers (2001)
# Name: title, dtype: object
